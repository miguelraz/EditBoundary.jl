# %% [markdown]
# # <font color="purple">Edit Boundary</font>
#
# <font color="#0066cc"><b>An Interactive Tool for Approximation of Complex Polygonal Contours in Julia</b></font>
#
# **Part of the Mesh Generator** [UNAMAlla 6](http://tikhonov.fciencias.unam.mx/unamalla)
#
# ## <font color="blue">Load Packages</font>

# %%
push!(LOAD_PATH,pwd()); include("Load_EditBoundary.jl");
# Out:
# WebIO._IJuliaInit()
# Gtk-Message: 14:47:39.496: Failed to load module "canberra-gtk-module"
# Gtk-Message: 14:47:39.497: Failed to load module "canberra-gtk-module"

# %% [markdown]
# ## 0. <font color="blue">Contour Creator</font>
#
# **Module for creating your polygon by mouse clicks**

# %%
@time contour_creator_menu();
# Out:
# "Contour Creator: Program for interactive creation of polygonal regions"
# "Press ENTER to create a new region or"
# "Press H to add a hole to a region"
# stdin>
# "Select an option"
# "[1] load an image"
# "[2] load a region"
# "[ENTER] use background grid"
# stdin>
#   2.978947 seconds (73.93 k allocations: 10.408 MiB, 0.65% gc time)
# "region saved in tests folder as: polygon_24-Mar-23-1454"

# %% [markdown]
# ## <font color="blue">1. Edit Boundary</font>
#
# **Module for polygon smoothing and simplification**

# %%
@time edit_boundary(threholds);
# Out:
# "Program for approximation of a polygonal region"
# "Choose a region"
# data: [
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields fill, fillcolor, hoverinfo, line, mode, opacity, type, x, and y",
#   "scatter with fields hoverinfo, mode, text, type, x, and y"
# ]
#
# layout: "layout with fields autosize, height, margin, showlegend, template, title, width, xaxis, and yaxis"
# data: [
# ...
